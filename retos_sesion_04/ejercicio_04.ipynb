# %% [markdown]
# ## Crea un archivo "ejercicio_04.ipynb", y diseña un juego

# %% [markdown]
# ### Reglas de juego
# 1. El jugador con las piezas blancas mueve primero
# 2. Cada jugador mueve 1 de sus piezas en su turno segun la posibilidad de cada pieza unica
# 3. Gana el jugador que logre hacer Jaque Mate al oponente
# 4. Ningún jugador puede exponer a su propio rey a un jaque mate
# 5. El jugador que declara jaque mate debe explicar la situación
# 6. Pieza tocada, pieza movida, esta regla de torneo consiste en que si tocamos una pieza con la intención de moverla, hay que hacerlo.
# 7. Evitar hablar durante la partida, Es totalmente prohibido hablar en el transcurso del juego salvo al momento de llamar al arbitro u ofrecer tablas, de lo contrario no hay razón para hacerlo. Esto se debe tomar en consideración a la concentración de ambos jugadores y respetar el espacio para pensar y calcular.

# %%
print ("Tablero de 8x8 distribuidos por espacios de color blanco y negro de forma intercalada")
print ("□■□■□■□■")
print ("■□■□■□■□")
print ("□■□■□■□■")
print ("■□■□■□■□")
print ("□■□■□■□■")
print ("■□■□■□■□")
print ("□■□■□■□■")
print ("■□■□■□■□")
# Out:
# Tablero de 8x8 distribuidos por espacios de color blanco y negro de forma intercalada
# □■□■□■□■
# ■□■□■□■□
# □■□■□■□■
# ■□■□■□■□
# □■□■□■□■
# ■□■□■□■□
# □■□■□■□■
# ■□■□■□■□

# %% [markdown]
# ### Descripción Piezas
# > Cada pieza de ajedrez tiene su propio estilo de movimiento.
# > Si hay una pieza del adversario en la casilla de destino, la pieza es capturada. La única excepción es el peón, que sólo puede capturar las piezas en diagonal hacia adelante.
#
# ### Torre
# * La torre se mueve a lo largo de filas y columnas.
#
# ### Caballo
# * El caballo se mueve avanzando dos y uno de lado. Es la única pieza que puede saltar sobre las demás. (no necesita que el camino esté despejado).
#
# ### Reyna
# * La dama mueve por columnas, filas y diagonales.
#
# ### Alfil
# * El alfil se mueve por las diagonales. Nunca cambia de color y por eso solemos hablar de alfil de casillas blancas o de negras, puesto que tenemos uno en cada color.
#
# ### Rey
# * El rey mueve una casilla en cualquier dirección. La casilla de destino no debe estar amenazada.
#
# ### Peón
# * El peón avanza una casilla, salvo desde su posición inicial, en la que puede avanzar una o dos. Solamente captura la pieza enemiga en diagonal.

# %%
# Diseño piezas

print ("Pieza TORRE")
print (" _   _   _ ")
print ("| |_| |_| |")
print (" \\       / ")
print ("  |     |  ")
print ("  |     |  ")
print ("  |     |  ")
print (" /       \\ ")
print ("|_________|")


print ("Pieza CABALLO")
print ("  |\\__")
print (" /   o\\__")
print ("|    ___='")
print ("|    \\")
print (" \\    \\")
print ("  >    \\")
print (" /      \\")
print ("|________|")

print ("Pieza ALFIL")
print ("    o")
print ("  /\\^/\\")
print (" |  /  )")
print (" | /  / ")
print ("  Y  / ")
print ("  |  |")
print ("  |  |")
print (" /    \\ ")
print ("|______|")

print ("Pieza REYNA")
print ("|\\ ,'`. /|")
print ("| `'`'`' |")
print (" \\      /")
print ("  |    |")
print ("  |    |")
print ("  |    |")
print ("  |    |")
print (" /      \\ ")
print ("|________|")

print ("Pieza REY")
print ("  = + =")
print ("|\\ ,'`. /|")
print ("| `'`'`' |")
print (" \\      /")
print ("  |    |")
print ("  |    |")
print ("  |    |")
print ("  |    |")
print (" /      \\ ")
print ("|________|")

print ("Pieza Peón")
print ("    __")
print ("   (  )")
print ("    ><")
print ("   |  |")
print ("  /    \\")
print (" |______|")
# Out:
# Pieza TORRE
#  _   _   _
# | |_| |_| |
#  \       /
#   |     |
#   |     |
#   |     |
#  /       \
# |_________|
# Pieza CABALLO
#   |\__
#  /   o\__
# |    ___='
# |    \
#  \    \
#   >    \
#  /      \
# |________|
# Pieza ALFIL
#     o
#   /\^/\
#  |  /  )
#  | /  /
#   Y  /
#   |  |
#   |  |
#  /    \
# |______|
# Pieza REYNA
# |\ ,'`. /|
# | `'`'`' |
#  \      /
#   |    |
#   |    |
#   |    |
#   |    |
#  /      \
# |________|
# Pieza REY
#   = + =
# |\ ,'`. /|
# | `'`'`' |
#  \      /
#   |    |
#   |    |
#   |    |
#   |    |
#  /      \
# |________|
# Pieza Peón
#     __
#    (  )
#     ><
#    |  |
#   /    \
#  |______|
